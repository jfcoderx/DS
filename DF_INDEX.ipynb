# %% [markdown]
# <a href="https://colab.research.google.com/github/jfcoderx/Data-Sciense/blob/main/DF_INDEX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data = {
                            'Yil': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014],
                            'Aholi': [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
                            'Temp': [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53]
                         }, 
                            index=list(range(11, 19))
                  )

df['Money'] = 30


df
# Out:
#      Yil  Aholi  Temp  Money
# 11  2021   33.9  1.54     30
# 12  2020   33.5  1.48     30
# 13  2019   32.9  1.56     30
# 14  2018   32.5  1.62     30
# 15  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 17  2015   30.9  1.64     30
# 18  2014   28.5  1.53     30

# %%
df.index
# Out:
# Int64Index([11, 12, 13, 14, 15, 16, 17, 18], dtype='int64')

# %%
malumot_ustunlari = df.columns
malumot_ustunlari
# Out:
# Index(['Yil', 'Aholi', 'Temp', 'Money'], dtype='object')

# %%
'Aholi' in malumot_ustunlari
# Out:
# True

# %% [markdown]
# Aslida df.index ham df.columns ham index degan obyekt qaytararkan

# %%
df2 = pd.DataFrame({
                    'Uzb':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
                    'Kaz':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
                    })
df2
# Out:
#        Uzb   Kaz
# 2021  33.9  18.9
# 2020  33.5  18.7
# 2019  32.9  18.5
# 2018  32.5  18.3
# 2017  31.9  18.1
# 2016   NaN  17.8

# %%
davlatlar = df2.columns
davlatlar
# Out:
# Index(['Uzb', 'Kaz'], dtype='object')

# %%
'Taj' in davlatlar
# Out:
# False

# %%
2000 in df2.index
# Out:
# False

# %% [markdown]
# Buni qulay tomoni endi siz ustunlar orqali ham malumotlarni tekshirishimiz mumkin ekan, misol davlatlarga oid millionlab malumot berilgan, shu mamlakatlar ichida Taj bormi yoqmi oson tekshira olarkanmiz<br>
# yani yillar boyicha ham topish mumkin ekan, misol 2000 yil malumotlari bormi

# %% [markdown]
# Indexlar bilan listlarni ishlagandek ishlashimiz mumkin, farqi uni ozgartirib bolmaydi

# %%
df.index[2:7]
# Out:
# Int64Index([13, 14, 15, 16, 17], dtype='int64')

# %% [markdown]
# bu indeklarni yana bir foyda tomoni, ikta katta malumotlarni solishtirganimizda biz ustunlardan foydalanishimiz mumkin, indekslardan foydalanashimiz mumkin.

# %%
per1 = pd.DataFrame({
                    'username':{
                                 "anvar":"anvarbek223", 
                                 "olim":"olimtoy", 
                                 "maryam":"mary334455",
                                 "javohir":"javohir445"
                               },
                    'email':{
                                 "anvar":"anvar@gmail.com",
                                 "olim":"olim@mail.ru",
                                 "maryam":"mary33@gmail.com",
                                 "javohir":"javohir445@gmail.com"
                            }
                   })

per1
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
per2 = pd.DataFrame({
                  'username':{
                              "olim":"olimjon21",
                              "maryam":"maryam2020"
                             },
                  'email':{
                              "olim":"olimjon21@mail.ru", 
                              "maryam":"maryam20@gmail.com"
                          }
                    })

per2
# Out:
#           username               email
# olim     olimjon21   olimjon21@mail.ru
# maryam  maryam2020  maryam20@gmail.com

# %%
per = per1.append(per2)
per
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %% [markdown]
# indexlar va ustunlar takrorlanishi mumkin, misol barcha olimga oid malumotlarni ajratib ol deyishi mumkin

# %% [markdown]
# INDEX lar ham alohida obyekt bolgani uchun pd.index qilib alohida yaratib olish mumkin

# %%
ind = pd.Index(['olim', 'Jasur', 'Ikrom'])
ind
# Out:
# Index(['olim', 'Jasur', 'Ikrom'], dtype='object')

# %% [markdown]
# alohida indekslar yaratib olishimiz bizga katta malumotlarni tekshirganimizda kerak bolishi mumkin, misol uchun biz uchta ismni ajratib oldik va malumotlarimiz ichidan shu 3tasi bor yoqligini tekshiramiz

# %%
ind.isin(per.index)
# Out:
# array([ True, False, False])

# %% [markdown]
# Demak bundan korinadiki, Olim bor ekan, Nafisa bilan Hamida yoq ekan

# %%
per.index.difference(ind) # per malumotlarimiz indeksi bilan bizni yangi indeksimiz ortasidagi farqni korsat degani
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %% [markdown]
# demak anvar, javohir, maryam degan foydalanuvchilar bizni per malumotimizda yangi indeks ichida yoqlari ekan

# %%
ind.difference(per.index)
# Out:
# Index(['Ikrom', 'Jasur'], dtype='object')

# %% [markdown]
# demak Jasur, Ikrom degan foydalanuvchilar bizni yangi indeksimizda per malumotlar indeksi ichida yoqlari ekan

# %%
ind.union(per.index)
# Out:
# Index(['Ikrom', 'Jasur', 'anvar', 'javohir', 'maryam', 'maryam', 'olim',
#        'olim'],
#       dtype='object')

# %%
ind
# Out:
# Index(['olim', 'Jasur', 'Ikrom'], dtype='object')

# %%
ind.delete(-1)
# Out:
# Index(['olim', 'Jasur'], dtype='object')

# %%
ind.drop('olim')
# Out:
# Index(['Jasur', 'Ikrom'], dtype='object')

# %%
ind = ind.insert(-1, 'olim')
ind
# Out:
# Index(['olim', 'Jasur', 'olim', 'Ikrom'], dtype='object')

# %%
ind.is_unique
# Out:
# False

# %%
ind.is_monotonic
# Out:
# False

# %%
ind.unique()
# Out:
# Index(['olim', 'Jasur', 'Ikrom'], dtype='object')

# %% [markdown]
# ---
# ---

# %%
df
# Out:
#      Yil  Aholi  Temp  Money
# 11  2021   33.9  1.54     30
# 12  2020   33.5  1.48     30
# 13  2019   32.9  1.56     30
# 14  2018   32.5  1.62     30
# 15  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 17  2015   30.9  1.64     30
# 18  2014   28.5  1.53     30

# %%
# df dagi indexlarni ozgartiramiz
df.index = [21, 20, 19, 18, 17, 16, 15, 14]
df
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30
# 14  2014   28.5  1.53     30

# %%
# Bu dataframeni jadvalni tartibi biz kiritgan dastlabki malumotlar asosida boladi
# bularni ham indexisiga kora tartiblashimiz mumkin

ind = [21, 20, 19, 18, 17, 16, 15, 14]
ind.sort()
ind
# Out:
# [14, 15, 16, 17, 18, 19, 20, 21]

# %%
# qayta indeklash
df.reindex(ind)
# Out:
#      Yil  Aholi  Temp  Money
# 14  2014   28.5  1.53     30
# 15  2015   30.9  1.64     30
# 16  2016   31.4  1.66     30
# 17  2017   31.9  1.65     30
# 18  2018   32.5  1.62     30
# 19  2019   32.9  1.56     30
# 20  2020   33.5  1.48     30
# 21  2021   33.9  1.54     30

# %%
ind = [21, 20, 19, 18, 17, 16, 13, 12]
ind.sort()
ind
# Out:
# [12, 13, 16, 17, 18, 19, 20, 21]

# %%
# qayta indeklash, asl DataFrame ni ozgartirmaydi
df.reindex(ind)
# Out:
#        Yil  Aholi  Temp  Money
# 12     NaN    NaN   NaN    NaN
# 13     NaN    NaN   NaN    NaN
# 16  2016.0   31.4  1.66   30.0
# 17  2017.0   31.9  1.65   30.0
# 18  2018.0   32.5  1.62   30.0
# 19  2019.0   32.9  1.56   30.0
# 20  2020.0   33.5  1.48   30.0
# 21  2021.0   33.9  1.54   30.0

# %%
df
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30
# 14  2014   28.5  1.53     30

# %%
# qayta indeklash, asl DataFrame ni ozgartirmaydi
df.reindex([21, 20, 19, 18, 17, 16, 15, 14].sort())
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30
# 14  2014   28.5  1.53     30

# %%
df
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30
# 14  2014   28.5  1.53     30

# %%
# ichidan malumotlarni index orqali ajratib olishimiz ham mumkin
# yoki alohida indexli DataFrame ham hosil qilishimiz mumkin
df.reindex([21, 20, 22])
# Out:
#        Yil  Aholi  Temp  Money
# 21  2021.0   33.9  1.54   30.0
# 20  2020.0   33.5  1.48   30.0
# 22     NaN    NaN   NaN    NaN

# %%
# NaN qiymatlar ornini bazi metodlar bilan toldirsak boladi
# masalan nearest - eng yaqinidagi qiymatlar bilan toldiradi
df.reindex(range(10, 22))
# Out:
#        Yil  Aholi  Temp  Money
# 10     NaN    NaN   NaN    NaN
# 11     NaN    NaN   NaN    NaN
# 12     NaN    NaN   NaN    NaN
# 13     NaN    NaN   NaN    NaN
# 14  2014.0   28.5  1.53   30.0
# 15  2015.0   30.9  1.64   30.0
# 16  2016.0   31.4  1.66   30.0
# 17  2017.0   31.9  1.65   30.0
# 18  2018.0   32.5  1.62   30.0
# 19  2019.0   32.9  1.56   30.0
# 20  2020.0   33.5  1.48   30.0
# 21  2021.0   33.9  1.54   30.0

# %%
#lekin bu usulimiz uncha togri usul emas
df.reindex(range(10, 22), method='nearest')
# Out:
#      Yil  Aholi  Temp  Money
# 10  2014   28.5  1.53     30
# 11  2014   28.5  1.53     30
# 12  2014   28.5  1.53     30
# 13  2014   28.5  1.53     30
# 14  2014   28.5  1.53     30
# 15  2015   30.9  1.64     30
# 16  2016   31.4  1.66     30
# 17  2017   31.9  1.65     30
# 18  2018   32.5  1.62     30
# 19  2019   32.9  1.56     30
# 20  2020   33.5  1.48     30
# 21  2021   33.9  1.54     30

# %% [markdown]
# Misol dollarning yoki biror aksiyalarning ozgarish tendensiyalari, ular hammasi malumotlari berilgan lekin malum kunlarda qayd qilishda xatolik bolgan yoki qayd qilmagan osha malumotlar oraliglarini to`ldirish uchun ishlatib yuborsak boladi

# %%
#oxiridagi bilan toldirib qoyadi
df.reindex(range(10, 22), method='ffill')
# Out:
#      Yil  Aholi  Temp  Money
# 10  2014   28.5  1.53     30
# 11  2014   28.5  1.53     30
# 12  2014   28.5  1.53     30
# 13  2014   28.5  1.53     30
# 14  2014   28.5  1.53     30
# 15  2015   30.9  1.64     30
# 16  2016   31.4  1.66     30
# 17  2017   31.9  1.65     30
# 18  2018   32.5  1.62     30
# 19  2019   32.9  1.56     30
# 20  2020   33.5  1.48     30
# 21  2021   33.9  1.54     30

# %%
# biror ustunni tashlab yuborsak, misol yil kerak emas, chunki indekslarimiz shu yillarga mos
df.reindex(columns=['Aholi', 'Temp', 'Money'])
# Out:
#     Aholi  Temp  Money
# 21   33.9  1.54     30
# 20   33.5  1.48     30
# 19   32.9  1.56     30
# 18   32.5  1.62     30
# 17   31.9  1.65     30
# 16   31.4  1.66     30
# 15   30.9  1.64     30
# 14   28.5  1.53     30

# %%
df.reindex(columns=['Aholi', 'Temp', 'Money', 'yyyy'])
# Out:
#     Aholi  Temp  Money  yyyy
# 21   33.9  1.54     30   NaN
# 20   33.5  1.48     30   NaN
# 19   32.9  1.56     30   NaN
# 18   32.5  1.62     30   NaN
# 17   31.9  1.65     30   NaN
# 16   31.4  1.66     30   NaN
# 15   30.9  1.64     30   NaN
# 14   28.5  1.53     30   NaN

# %%
df2
# Out:
#        Uzb   Kaz
# 2021  33.9  18.9
# 2020  33.5  18.7
# 2019  32.9  18.5
# 2018  32.5  18.3
# 2017  31.9  18.1
# 2016   NaN  17.8

# %%
# SAMPLE HEAD ga azgina oxshab ketib tasodifiy bitta qiymatni olib beradi, 
# ichiga argument qoysak oshancha tasodifiy qiymatni chiqarib beradi
# har safar yangi tasodiflarni chiqaradi
df.sample()
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30

# %%
df.sample(3)
# Out:
#      Yil  Aholi  Temp  Money
# 14  2014   28.5  1.53     30
# 17  2017   31.9  1.65     30
# 21  2021   33.9  1.54     30

# %%
# bir vaqtning ozida ham ustunlar ham qatorlar boyicha qayta indeklamoqchi bolsak
# Shunday qilib biz istalgan ustunlarni va istalgan qatorlarni ajratib olishimiz mumkin

df.loc[[14, 18, 21], ['Yil', 'Temp']]
# Out:
#      Yil  Temp
# 14  2014  1.53
# 18  2018  1.62
# 21  2021  1.54

# %%
# DataFrameni malum qatorlarini ustunlarini tashlab yuborishni koramiz

df1 = df.drop(14)

# 10-indeksni qatorni tashlab yuboradi va yangi ozgaruvchiga saqlab oladi

df1
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30

# %%
# bir nechta qatorlarni ham tashlab yuborishimiz mumkin

df.drop([14, 15, 21])
# Out:
#      Yil  Aholi  Temp  Money
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30

# %%
# ustunlarni shunday tashlab yubormoqchi bolsak

df.drop('Yil', axis=1)
# Out:
#     Aholi  Temp  Money
# 21   33.9  1.54     30
# 20   33.5  1.48     30
# 19   32.9  1.56     30
# 18   32.5  1.62     30
# 17   31.9  1.65     30
# 16   31.4  1.66     30
# 15   30.9  1.64     30
# 14   28.5  1.53     30

# %%
# bir nechta ustunlarni tashlab yubormoqchi bolsak

df.drop(['Yil', 'Money'], axis=1)

# yuqoridagi misollarda ham aslida default qiymat sifatida, axis=0 turibdi
# Out:
#     Aholi  Temp
# 21   33.9  1.54
# 20   33.5  1.48
# 19   32.9  1.56
# 18   32.5  1.62
# 17   31.9  1.65
# 16   31.4  1.66
# 15   30.9  1.64
# 14   28.5  1.53

# %%
# bir nechta ustunlarni tashlab yubormoqchi bolsak

df.drop(['Yil', 'Money'], axis='columns')

# axis ni orniga columsn deb ham yozsak osha natijani beradi
# Out:
#     Aholi  Temp
# 21   33.9  1.54
# 20   33.5  1.48
# 19   32.9  1.56
# 18   32.5  1.62
# 17   31.9  1.65
# 16   31.4  1.66
# 15   30.9  1.64
# 14   28.5  1.53

# %%
df1
# Out:
#      Yil  Aholi  Temp  Money
# 21  2021   33.9  1.54     30
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 18  2018   32.5  1.62     30
# 17  2017   31.9  1.65     30
# 16  2016   31.4  1.66     30
# 15  2015   30.9  1.64     30

# %%
# agar biz joyida shu qilganlar ozgarishlarim asl ozgaruvchiga ozgarishini xohlamoqchi bolsak
# inplace = True dan foydalanamiz

df1.drop([16, 18, 21], inplace=True)
df1
# Out:
#      Yil  Aholi  Temp  Money
# 20  2020   33.5  1.48     30
# 19  2019   32.9  1.56     30
# 17  2017   31.9  1.65     30
# 15  2015   30.9  1.64     30
