# %% [markdown]
# <a href="https://colab.research.google.com/github/jfcoderx/Data-Sciense/blob/main/PD_DATASET_STATISTIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Keyingi mashqlar uchun ma'lumotlarni Githubdan yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni', 'aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
# 2020 va 2021 yilda GM Uzbekistan tomonidan jami sotilgan moshinalar soni
df2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
# ustunlar boyicha yigindilar talab qilinsa
# yani 2020 va 2021 yillar bo'yicha sotilgan markalar yigindisi
df2.sum(axis=1)
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
# ularning o'rtacha qiymati

df2.mean(axis=1)
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
# maydoni eng kichikining indeksi
# aholisi eng kichigining indeksi

df.idxmin()
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: object

# %%
# maydoni eng kattasining indeksi
# aholisi eng kattasining indeksi

df.idxmax()
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: object

# %%
# argmax biror ustun boyicha eng kattasining tartib raqamini chiqaradi
# faqat SERIESLAR uchun o'rinli

df['maydoni'].argmax()
# Out:
# 8

# %%
df.iloc[8]
# Out:
# maydoni     160000.0
# aholisi    1200000.0
# Name: Qoraqalpogʻiston Respublikasi, dtype: float64

# %%
df['aholisi'].argmin()
# Out:
# 10

# %%
print(df['aholisi'].idxmax(), 'aholisi', df['aholisi'].max())
# Out:
# Toshkent viloyati aholisi 4450000.0

# %%
print(df['maydoni'].idxmax())
print(df['maydoni'].max())
# Out:
# Qoraqalpogʻiston Respublikasi
# 160000.0

# %%
df2
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317
# Gentra  30368  26266

# %%
df2.idxmin()
# Out:
# 2020     Labo
# 2021    Spark
# dtype: object

# %%
df2.idxmax()
# Out:
# 2020    Cobalt
# 2021    Cobalt
# dtype: object

# %%
# FUNKSIYALAR

# count - NaN bo'lmagan qiymatlar soni

# median - qiymatlar medianini hisbolash

# mad - mean absolute deviation

# prod - barcha qiymatlar ko'paytmasi

# var - variance (dispersiya)

# std - standart deviation (standart chetlanis)

# skew - skewness

# kurt - kurtosis

# cumsum - cumulative sum

# cummin va cummax- cumulative min and max

# cumprod - cumulative product

# diff - arifmetik farq (difference)

# pct_change - percent changes

# %%
# onlayn bozordagi Mersedez narxlari
d = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv")
d.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
# chindan anchagina katta jadval
d.shape
# Out:
# (13119, 9)

# %%
# oxiridan 5 ta qiymatni ko'rmoqchi bo'lsak
d.tail()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
# tasodiviy 10 ta qiymatni ko'rmoqchi bo'lsak
d.sample(10)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 4414   GLE Class  2016  26572    Automatic    34333   Diesel  260  42.8
# 3132     C Class  2019  20980    Semi-Auto    14208   Petrol  145  44.1
# 6204     B Class  2019  27949    Semi-Auto     1732   Petrol  145  37.7
# 3085     C Class  2019  19980    Semi-Auto    15057   Diesel  145  64.2
# 4988   GLC Class  2020  39980    Semi-Auto     3999   Diesel  145  40.9
# 4691   GLB Class  2020  36880    Semi-Auto     3001   Diesel  145  44.8
# 8599     B Class  2019  24589    Semi-Auto     1000   Diesel  145  55.4
# 7154     A Class  2020  25879    Semi-Auto     1000   Petrol  145  53.3
# 2004     A Class  2018  22022    Semi-Auto     3512   Petrol  145  53.3
# 1099     C Class  2017  23990    Semi-Auto    19784   Petrol  145  42.2
#
#       engineSize
# 4414         3.0
# 3132         1.5
# 6204         2.0
# 3085         2.1
# 4988         2.0
# 4691         2.0
# 8599         2.0
# 7154         1.3
# ...

# %%
# hayotda turli jadvallar bilan ishlaganimizda bazi qiymatlar to'ldirilmagan bo'ladi
# va NaN qiymatni oladi, info() bizga shularni ko'rishga yordam beradi

# %%
# bu kattagina jadval bo'lgani uchun biz unga birrovgina ko'z yugurtirib chiqa olmaymiz
# bizga bazi bir umumlashtiruvchi funksiyalar yordam beradi

d.info()

# demak bu juda ham yaxshi dataset
# chunki uning hamma qiymatlari to'ldirilgan, kiritilgan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 922.6+ KB

# %%
# yuqoridagi dtype dagi object bizga stringlar mavjudligini bildiradi

d.describe()

# bu fuksiya orqali biz barcha raqamlarga oid ustunlarni chiqaradi va ularga oid
# umumlashtiruvchi malumotlar bilan birga
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
# count - NaN qiymatga ega bo'lmagan qiymatlar
# mean - ortacha qiymati, demak ortacha yil 2017ga togri kelarkan 
# std - ortacha ogish, +-2 year uchun, demak mashinalarning 60-70%
# 2015 - 2019 ga togri kelarkan, (ustun uchun standart chetlanish)
# min - ustun uchun minimal
# 25/ 50/ 75% - qiymatlarning 25/50/75% shu oraliqda

# %%
d['price'].plot.hist(bins=30)

# %%
d['year'].plot.hist(bins=30)

# %%
# KORRELASIYA
# 2ta ustun bor
# biz shu 2 ustun orasidagi o'xshashlikni
# korrelasiya orqali tekshira olamiz

# %%
data = {
    'age': list(range(10, 70, 10)),
    'year': list(range(2010, 1950, -10))
}

obj = pd.DataFrame(data)
obj
# Out:
#    age  year
# 0   10  2010
# 1   20  2000
# 2   30  1990
# 3   40  1980
# 4   50  1970
# 5   60  1960

# %%
# bular orasida bogliqlik bormi?
# albatta bor, yosh kattargan sari, tugilgan yil kichik boladi
# shuni tekshirishda korrelasiya ishlatiladi

# %%
obj['age'].corr(obj['year'])
# Out:
# -0.9999999999999998

# %%
# bu degani ikkalasi orasidagi bogliqlik 99%
# faqat teskari tartibdagi bogliqlik (-) manfiy borligi uchun

obj['year'].corr(obj['age'])
# Out:
# -0.9999999999999998

# %%
d
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
# Misol, mashinaning ishlab chiqarilgan yili va uning yurgan masofasi ortasida
# bogliqlik bor, mashina qancha eski bo'lsa u shuncha ko'p yurgan bo'lishi mumkin
# bu bogliqlik qancha foiz

d['year'].corr(d['mileage'])
# Out:
# -0.7380268515364232

# %%
# 73% demak kattagina bogliqlik borakan
# yani yili oshgani sari, yurgan yoli uzunligi kamayadi
# (-) teskari boglanishni korsatadi
# SUNIY INTELEKT kelajakda aynan shu kabi metodlardan foydalangan holda baholaydi

# %%
# biz hozir har bir ustunni boshqasi bilan solishtirib turibmiz
# aslida tezkorroq yolidan foydalanish kerak

d.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
d.corr()[abs(d.corr()) > 0.7]
# Out:
#                 year  price   mileage  tax  mpg  engineSize
# year        1.000000    NaN -0.738027  NaN  NaN         NaN
# price            NaN    1.0       NaN  NaN  NaN         NaN
# mileage    -0.738027    NaN  1.000000  NaN  NaN         NaN
# tax              NaN    NaN       NaN  1.0  NaN         NaN
# mpg              NaN    NaN       NaN  NaN  1.0         NaN
# engineSize       NaN    NaN       NaN  NaN  NaN         1.0

# %%
d.corr()[abs(d.corr()) > 0.5]
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027       NaN       NaN         NaN
# price       0.520712  1.000000 -0.537214       NaN       NaN    0.516126
# mileage    -0.738027 -0.537214  1.000000       NaN       NaN         NaN
# tax              NaN       NaN       NaN  1.000000 -0.513742         NaN
# mpg              NaN       NaN       NaN -0.513742  1.000000         NaN
# engineSize       NaN  0.516126       NaN       NaN       NaN    1.000000

# %%
# bir ustunni boshqa ustunlar bilan bogliqligini korish uchun

d.corrwith(d['price']) # demak narx bilan qolgan ustunlar orasidagi bogliqlikni korish mumkin
# Out:
# year          0.520712
# price         1.000000
# mileage      -0.537214
# tax           0.268717
# mpg          -0.438445
# engineSize    0.516126
# dtype: float64

# %% [markdown]
# ---
# ---

# %%
# Noyob (takrorlanmas) qiymatlar

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
obj.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
d
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...

# %%
# misol model ustunini olaylik, unda 13119 ta qator bor, 
# lekin bu shuncha model degani emas, ichida juda kop takrorlangan
# modellar bor, takrorlanmaganlarini korish uchun

# %%
models = d['model'].unique()
models
# Out:
# array([' SLK', ' S Class', ' SL CLASS', ' G Class', ' GLE Class',
#        ' GLA Class', ' A Class', ' B Class', ' GLC Class', ' C Class',
#        ' E Class', ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#        ' V Class', ' M Class', ' CL Class', ' GLS Class', ' GLB Class',
#        ' X-CLASS', '180', ' CLK', ' R Class', '230', '220', '200'],
#       dtype=object)

# %%
models.sort()
models
# Out:
# array([' A Class', ' B Class', ' C Class', ' CL Class', ' CLA Class',
#        ' CLC Class', ' CLK', ' CLS Class', ' E Class', ' G Class',
#        ' GL Class', ' GLA Class', ' GLB Class', ' GLC Class',
#        ' GLE Class', ' GLS Class', ' M Class', ' R Class', ' S Class',
#        ' SL CLASS', ' SLK', ' V Class', ' X-CLASS', '180', '200', '220',
#        '230'], dtype=object)

# %%
models.size
# Out:
# 27

# %%
# har bir modeldan nechataligini kormoqchi bo'lsak

d['model'].value_counts()
# Out:
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: model, dtype: int64

# %%
# year uchun yuqoridagi misolni korib chiqamiz

years = d['year'].unique()
years
# Out:
# array([2005, 2017, 2016, 2011, 2018, 2012, 2019, 2020, 2014, 2015, 2006,
#        2010, 2004, 2008, 2013, 2007, 2009, 2003, 2001, 2002, 1998, 2000,
#        1997, 1999, 1970])

# %%
years.sort()
years
# Out:
# array([1970, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019, 2020])

# %%
years.size
# Out:
# 25

# %%
d['fuelType'].unique()
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Other'], dtype=object)

# %%
# har bir fuelType nechataligini kormoqchi bo'lsak

d['fuelType'].value_counts()
# Out:
# Diesel    9187
# Petrol    3752
# Hybrid     173
# Other        7
# Name: fuelType, dtype: int64

# %%
# har bir transmission nechataligini kormoqchi bo'lsak

d['transmission'].value_counts()
# Out:
# Semi-Auto    6848
# Automatic    4825
# Manual       1444
# Other           2
# Name: transmission, dtype: int64

# %%
# alohida bir nechta modellarni ajratib olaylik
models = [' SLK', ' B Class'] # modellarni kiritguncha bo'sh joy qo'ygan bu mutlaqo tavsiya qilinmaydi
filtr = d['model'].isin(models) # [' SLK', ' B Class'] shu modellar ichidan tekshir barcha modellarni
filtr
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114    False
# 13115     True
# 13116    False
# 13117    False
# 13118    False
# Name: model, Length: 13119, dtype: bool

# %%
# demak tuzgan filtrimiz asosida jadval chiqarib ololdik
# yani 2 modelni jadvallarini ajratib ololdik

d[filtr]
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0           SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 12      B Class  2019  23750    Automatic      278   Diesel  145  55.4
# 15      B Class  2017  15890    Automatic    24841   Diesel  150  68.9
# 18      B Class  2017  17513    Automatic    14128   Diesel  150  68.9
# 40          SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 13033   B Class  2016  14599    Automatic    28156   Diesel   20  68.9
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13108       SLK  2016  17499    Automatic    30128   Diesel   30  70.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
# 13115   B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 0             1.8
# 12            2.0
# 15            1.5
# 18            2.1
# ...

# %%
# faqat Petrolda yuradigan mashinalarni ajratiboladigan bolsak

filtr_petrol = d['fuelType'].isin(['Petrol'])
d[filtr_petrol]
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13098     C Class  2019   24499    Automatic    10635   Petrol  145  44.1
# 13099     C Class  2019   23994    Automatic    12794   Petrol  145  46.3
# 13102   GLC Class  2017   35999    Automatic    18507   Petrol  150  34.0
# 13106     C Class  2019   27999    Automatic     6537   Petrol  145  44.1
# 13111     B Class  2019   19344    Automatic    15257   Petrol  145  45.6
#
#        engineSize
# 0             1.8
# 2             5.5
# 3             4.0
# ...

# %%
# yili 2020 yil bolgan jadvallarni chiqarsak
d[d['year'] == 2020] # == d[d['year'].isin([2020])]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 10        A Class  2020  32980    Automatic      606   Petrol  145  35.8
# 11        A Class  2020  26980    Automatic     1000   Diesel  145  62.8
# 33        A Class  2020  28128    Automatic     2563   Petrol  145  47.9
# 38        C Class  2020  31790    Automatic     3500   Petrol  145  64.2
# 57      GLE Class  2020  48995    Automatic     3000   Diesel  145  36.7
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13053     A Class  2020  27995    Automatic     2500   Diesel  145  67.3
# 13056   GLE Class  2020  58450    Automatic     1159   Diesel  150  32.8
# 13113     C Class  2020  30999    Automatic     1000   Diesel  145  64.2
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 10            2.0
# 11            1.5
# 33            1.3
# ...

# %%
# yili 2020, narxi 35000 qimmat mashinalarni tanlaylik

d[(d['year'] == 2020) & (d['price'] > 35000)]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 57      GLE Class  2020  48995    Automatic     3000   Diesel  145  36.7
# 120       E Class  2020  35438    Automatic     3500   Diesel  145  42.8
# 126     GLE Class  2020  54995    Automatic     6700   Diesel  150  32.8
# 151     GLC Class  2020  37998    Semi-Auto     5538   Diesel  150  40.9
# 632       V Class  2020  43950    Semi-Auto     2859   Diesel  145  36.2
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 12968     C Class  2020  35490    Automatic     2690   Diesel  145  48.7
# 13026     C Class  2020  38400    Automatic     2384   Diesel  145  46.3
# 13038     C Class  2020  68995    Automatic     2000   Petrol  145  28.0
# 13056   GLE Class  2020  58450    Automatic     1159   Diesel  150  32.8
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
#
#        engineSize
# 57            2.0
# 120           2.0
# 126           3.0
# ...

# %%
d[d.transmission == 'Automatic']
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# ...
