# %% [markdown]
# <a href="https://colab.research.google.com/github/jfcoderx/Data-Sciense/blob/main/DS_3_Modul_3_Amaliyot_tozalash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## 3.2 Ma'lumotlarni tayyorlash
#
# # **AMALIYOT**
# ## Ma'lumotlarga ishlov berish

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mukhammad-irmatov/health_dataset/main/healt_info.csv")
df
# Out:
#            Sno  AGE     SEX CASTE_NAME CATEGORY_CODE  \
# 0            1   56  Female         BC            M6
# 1            2   37    Male         BC            M6
# 2            3   50    Male         BC            M6
# 3            4   45    Male         BC            M6
# 4            5   54    Male         BC            M6
# ...        ...  ...     ...        ...           ...
# 335389  335390   65    Male         SC            S3
# 335390  335391   54  Female         OC           S12
# 335391  335392   19  Female         SC           S12
# 335392  335393   50    Male         BC            S9
# 335393  335394   46  Female         SC           S12
#
#                    CATEGORY_NAME SURGERY_CODE  \
# 0                     NEPHROLOGY         M6.5
# 1                     NEPHROLOGY         M6.5
# 2                     NEPHROLOGY         M6.5
# 3                     NEPHROLOGY         M6.5
# 4                     NEPHROLOGY         M6.5
# ...                          ...          ...
# 335389    OPHTHALMOLOGY  SURGERY         SU66
# 335390          MEDICAL ONCOLOGY      S12.1.4
# 335391          MEDICAL ONCOLOGY     S12.28.1
# 335392  GENITO URINARY SURGERIES       S9.3.4
# 335393          MEDICAL ONCOLOGY      S12.2.1
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE   MANDAL_NAME  ...        CLAIM_DATE  \
# 0                        Lolugu       Ponduru  ...  22-03-2017 20:25
# 1                     Borivanka        Kaviti  ...  22-03-2017 20:25
# 2                   Kapasakuddi        Kaviti  ...  22-03-2017 20:25
# 3                   Telikipenta   Sarubujjili  ...  22-03-2017 20:25
# 4                 Thandemvalasa    Srikakulam  ...  22-03-2017 20:25
# ...                         ...           ...  ...               ...
# 335389             Chintalapudi        Ponnur  ...  04-08-2017 21:23
# 335390  Udayagiri @ Kondayapale     Udayagiri  ...  02-08-2017 19:11
# 335391                  Vinduru         Gudur  ...  04-10-2017 19:46
# 335392                Duppituru  Atchutapuram  ...  04-08-2017 20:59
# 335393             Ananthavaram  Mummidivaram  ...  09-08-2017 19:43
#
#        CLAIM_AMOUNT                                          HOSP_NAME  \
# 0             11000            Rims Govt. General Hospital, Srikakulam
# 1             11000            Rims Govt. General Hospital, Srikakulam
# 2             11500            Rims Govt. General Hospital, Srikakulam
# 3             11000            Rims Govt. General Hospital, Srikakulam
# 4             11000            Rims Govt. General Hospital, Srikakulam
# ...             ...                                                ...
# 335389        23320                                Sankar Eye Hospital
# 335390         7140  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...
# 335391         5000                                    M.N.J.Hospitals
# 335392        25000             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL
# 335393         2040  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...
#
#        HOSP_TYPE   HOSP_DISTRICT      SURGERY_DATE    DISCHARGE_DATE  \
# 0              G      Srikakulam  06-08-2013 00:00  07-09-2013 00:00
# 1              G      Srikakulam  08-08-2013 00:00  09-09-2013 00:00
# 2              G      Srikakulam  15-08-2013 00:00  18-10-2013 00:00
# 3              G      Srikakulam  24-08-2013 00:00  27-09-2013 00:00
# 4              G      Srikakulam  31-08-2013 00:00  02-10-2013 00:00
# ...          ...             ...               ...               ...
# 335389         C          Guntur  09-06-2017 00:00  10-06-2017 00:00
# 335390         C       Hyderabad  06-06-2017 00:00  06-06-2017 00:00
# 335391         G       Hyderabad  09-06-2017 00:00  10-06-2017 00:00
# 335392         C  Vishakhapatnam  06-06-2017 00:00  10-06-2017 00:00
# 335393         C   East Godavari  07-06-2017 00:00  07-06-2017 00:00
#
#        Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 0                   NO            NaN                D
# 1                   NO            NaN                D
# 2                   NO            NaN                D
# 3                   NO            NaN                D
# 4                   NO            NaN                D
# ...                ...            ...              ...
# 335389              NO            NaN                D
# 335390              NO            NaN                D
# 335391              NO            NaN                D
# 335392              NO            NaN                D
# 335393              NO            NaN               MC
#
# [335394 rows x 23 columns]

# %% [markdown]
# Bu dataset sug'urta kompaniyasining real ma'lumotlardan tuzilgan. Bu datasetda 480000 qator sug'urta ma'lumotlar tashkil topgan.
# Quyida datasetning ba'zi ustunlari haqida qisqacha ma'lumot
#
# *   Sno = seriya raqami
# *   AGE = yoshi
# *   SEX = jinsi (female = ayol, male = erkak)
# *   CASTE_NAME = kasta nomi (Hindistonda har bir inson ma'lum bir kastaga oid bo'ladi)
# *   CATEGORY_CODE = kategoriya kodi
# *   CATEGORY_Name = kategoriya nomi
# *   SURGERY_CODE = operatsiya kodi
# *   Mandal_Name = mandal nomlanishi ya'ni familiyasi desak ham bo'ladi
# *   Mortality Y/N = vafot etgan yoki vafot etmaganligi
# *   MORTALITY_DATE = qachon vafot etganligi

# %% [markdown]
# ### **1-mashq**. Datasetdagi barcha takrorlangan qatorlar sonini toping

# %%
# Javobni shuyerga yozing

sum(df.duplicated())
# Out:
# 0

# %%
#@title **To'g'ri javob**
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# #### **2-mashq**. Datasetdagi quyidagi ustunlar o'chirib yuborilsin:<br>
# *   Sno
# *   CATEGORY_CODE
# *   SURGERY_CODE
# *   MANDAL_NAME
# *   DISTRICT_NAME
# *   HOSP_DISTRICT
# <BR>

# %%
# Javobni shuyerga yozing
df.drop(['Sno', 'CATEGORY_CODE', 'SURGERY_CODE', 'MANDAL_NAME', 'DISTRICT_NAME', 'HOSP_DISTRICT'], axis=1)
# Out:
#         AGE     SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56  Female         BC                NEPHROLOGY
# 1        37    Male         BC                NEPHROLOGY
# 2        50    Male         BC                NEPHROLOGY
# 3        45    Male         BC                NEPHROLOGY
# 4        54    Male         BC                NEPHROLOGY
# ...     ...     ...        ...                       ...
# 335389   65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390   54  Female         OC          MEDICAL ONCOLOGY
# 335391   19  Female         SC          MEDICAL ONCOLOGY
# 335392   50    Male         BC  GENITO URINARY SURGERIES
# 335393   46  Female         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 17 columns]

# %%
#@title **To'g'ri javob**
df.drop(['Sno','CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis='columns',inplace=True)
df
# Out:
#         AGE     SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56  Female         BC                NEPHROLOGY
# 1        37    Male         BC                NEPHROLOGY
# 2        50    Male         BC                NEPHROLOGY
# 3        45    Male         BC                NEPHROLOGY
# 4        54    Male         BC                NEPHROLOGY
# ...     ...     ...        ...                       ...
# 335389   65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390   54  Female         OC          MEDICAL ONCOLOGY
# 335391   19  Female         SC          MEDICAL ONCOLOGY
# 335392   50    Male         BC  GENITO URINARY SURGERIES
# 335393   46  Female         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 17 columns]

# %% [markdown]
# #### **3-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni unique funksiyasi orqali tekshiring.

# %%
# Javobni shuyerga yozing

df.SEX.unique()
# Out:
# array(['Female', 'Male', 'Male(Child)', 'Female(Child)', 'FEMALE'],
#       dtype=object)

# %%
#@title **To'g'ri javob**
df["SEX"].unique()
# Out:
# array(['Female', 'Male', 'Male(Child)', 'Female(Child)', 'FEMALE'],
#       dtype=object)

# %% [markdown]
# #### **4-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni **Erkak** va **Ayol** ga o'zgartiring:
# O'zgartirish quyidagicha bo'lsin:
#
#
# *   Male -> Erkak
# *   Male(child) -> Erkak
# *   Female - > Ayol
# *   Female(child) - Ayol
# *   MALE -> Erkak
# *   FEMALE -> Ayol

# %%
# Javobni shuyerga yozing

dic = {'Male': 'Erkak', 'Male(Child)': 'Erkak', 'Female': 'Ayol', 'FEMALE': 'Ayol', 'Female(Child)': 'Ayol'}
df.SEX = df.SEX.map(dic)
df.head(30)
# Out:
#     AGE    SEX  CASTE_NAME                       CATEGORY_NAME  \
# 0    56   Ayol          BC                          NEPHROLOGY
# 1    37  Erkak          BC                          NEPHROLOGY
# 2    50  Erkak          BC                          NEPHROLOGY
# 3    45  Erkak          BC                          NEPHROLOGY
# 4    54  Erkak          BC                          NEPHROLOGY
# 5    35  Erkak          OC                          NEPHROLOGY
# 6    52  Erkak          OC                          NEPHROLOGY
# 7    73  Erkak          BC                          NEPHROLOGY
# 8    56  Erkak          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 9    49  Erkak          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 10   52  Erkak          BC                          NEPHROLOGY
# 11   56  Erkak          SC                          CARDIOLOGY
# 12   65   Ayol          SC                          CARDIOLOGY
# 13   75  Erkak          OC                          CARDIOLOGY
# 14   52  Erkak          OC                          CARDIOLOGY
# 15   56  Erkak  Minorities                          CARDIOLOGY
# 16    1  Erkak          OC            COCHLEAR IMPLANT SURGERY
# 17   54   Ayol          SC  CARDIAC AND CARDIOTHORACIC SURGERY
# 18   48  Erkak          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 19   57   Ayol          OC                          CARDIOLOGY
# 20   55  Erkak          OC                          NEPHROLOGY
# 21   74   Ayol          BC                          CARDIOLOGY
# 22   57  Erkak          BC                          CARDIOLOGY
# 23   56  Erkak          BC  CARDIAC AND CARDIOTHORACIC SURGERY
# 24   31  Erkak          BC  ORTHOPEDIC  SURGERY AND PROCEDURES
# 25   68  Erkak          BC                          CARDIOLOGY
# 26   72   Ayol          BC                          CARDIOLOGY
# 27   66   Ayol          OC                          CARDIOLOGY
# 28   35  Erkak          BC                          CARDIOLOGY
# 29   72   Ayol          SC                          CARDIOLOGY
#
#                                               SURGERY             VILLAGE  \
# 0                    Maintenance Hemodialysis For Crf              Lolugu
# 1                    Maintenance Hemodialysis For Crf           Borivanka
# 2                    Maintenance Hemodialysis For Crf         Kapasakuddi
# 3                    Maintenance Hemodialysis For Crf         Telikipenta
# 4                    Maintenance Hemodialysis For Crf       Thandemvalasa
# 5                    Maintenance Hemodialysis For Crf      Phasigangupeta
# 6                    Maintenance Hemodialysis For Crf        Kranti Nagar
# 7                    Maintenance Hemodialysis For Crf         Bhoghapuram
# 8      Coronary Balloon Angioplasty with stent(00.45)              Vallur
# 9                             Coronary Bypass Surgery             Ward-15
# 10                   Maintenance Hemodialysis For Crf               Rajam
# 11              Management Of Acute MI With Angiogram          Thurlapadu
# 12  Medical Management of  Refractory Cardiac Failure            Pulipadu
# 13  Medical Management of  Refractory Cardiac Failure          Karlapalem
# 14  Medical Management of  Refractory Cardiac Failure             Ward-19
# 15              Management Of Acute MI With Angiogram              Tullur
# 16                           Cochlear Implant Surgery       Phirangipuram
# 17                            Coronary Bypass Surgery           Kolakalur
# 18                            Coronary Bypass Surgery            Vellalur
# 19              Management Of Acute MI With Angiogram       Phirangipuram
# 20                   Maintenance Hemodialysis For Crf  Ayyavari Polavaram
# 21              Management Of Acute MI With Angiogram            4th Ward
# 22              Management Of Acute MI With Angiogram           Kambakaya
# 23                            Coronary Bypass Surgery             Konduru
# 24  Excision Or Other Operations For Scaphoid Frac...          Laxmipuram
# 25              Management Of Acute MI With Angiogram         Matchalesam
# 26              Management Of Acute MI With Angiogram          Meghavaram
# 27              Management Of Acute MI With Angiogram             Chavali
# 28              Management Of Acute MI With Angiogram   Shermahammadpuram
# 29              Management Of Acute MI With Angiogram             Talagam
#
#         PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  CLAIM_AMOUNT  \
# 0   03-08-2013 20:38        12500  22-03-2017 20:25         11000
# 1   06-08-2013 07:26        12500  22-03-2017 20:25         11000
# 2   09-08-2013 18:30        12500  22-03-2017 20:25         11500
# 3   24-08-2013 19:37        12500  22-03-2017 20:25         11000
# 4   28-08-2013 17:03        12500  22-03-2017 20:25         11000
# 5   28-08-2013 17:30        12500  22-03-2017 20:25         11000
# 6   30-08-2013 07:53        12500  22-03-2017 20:25         11000
# 7   02-05-2014 15:11        12500  11-10-2017 19:34          5000
# 8   10-06-2014 17:02        40000  17-02-2017 19:21         40000
# 9   11-06-2014 20:41       115846  17-02-2017 19:21        115846
# 10  25-06-2014 08:45        12500  03-10-2017 20:37          6250
# 11  04-07-2014 15:12        30000  17-02-2017 18:54         30000
# 12  09-07-2014 10:17        40000  17-02-2017 18:54         40000
# 13  10-07-2014 20:59        40000  17-02-2017 18:54         40000
# 14  13-07-2014 18:09        40000  17-02-2017 18:54         25000
# 15  16-07-2014 21:08        30000  17-02-2017 18:54         30000
# 16  20-07-2017 20:20       520000  27-10-2017 19:54        520000
# 17  27-07-2014 18:01       115846  17-02-2017 19:22        108846
# 18  27-07-2014 18:01       115846  17-02-2017 19:22        110846
# 19  28-07-2014 08:37        30000  17-02-2017 18:54         30000
# 20  29-07-2014 14:58        12500  10-01-2017 02:04          2500
# 21  01-08-2014 17:51        30000  09-05-2017 18:35         30000
# 22  01-08-2014 17:49        30000  09-05-2017 18:35         25000
# 23  03-08-2014 15:44       115846  17-02-2017 19:22        110000
# 24  03-08-2014 10:23        15000  09-05-2017 18:35          5000
# 25  03-08-2014 14:53        30000  09-05-2017 18:35         30000
# 26  03-08-2014 12:19        30000  09-05-2017 18:35         10000
# 27  04-08-2014 12:21        30000  17-02-2017 18:54         20000
# 28  04-08-2014 12:15        30000  09-05-2017 18:36         30000
# 29  04-08-2014 18:23        30000  09-05-2017 18:36         25000
#
#                                   HOSP_NAME HOSP_TYPE      SURGERY_DATE  \
# 0   Rims Govt. General Hospital, Srikakulam         G  06-08-2013 00:00
# 1   Rims Govt. General Hospital, Srikakulam         G  08-08-2013 00:00
# 2   Rims Govt. General Hospital, Srikakulam         G  15-08-2013 00:00
# 3   Rims Govt. General Hospital, Srikakulam         G  24-08-2013 00:00
# 4   Rims Govt. General Hospital, Srikakulam         G  31-08-2013 00:00
# 5   Rims Govt. General Hospital, Srikakulam         G  31-08-2013 00:00
# 6             Govt General Hospital Kurnool         G  31-08-2013 00:00
# 7                      Queens Nri Hospitals         C  05-05-2014 00:00
# 8                         Karumuri Hospital         C  14-06-2014 00:00
# 9                         Karumuri Hospital         C  17-06-2014 00:00
# 10                     Queens Nri Hospitals         C  27-06-2014 00:00
# 11                        Karumuri Hospital         C  04-07-2014 00:00
# 12                        Karumuri Hospital         C  08-07-2014 00:00
# 13                        Karumuri Hospital         C  10-07-2014 00:00
# 14                        Karumuri Hospital         C  13-07-2014 00:00
# 15                        Karumuri Hospital         C  15-07-2014 00:00
# 16                         Ent Nursing Home         C  16-08-2017 00:00
# 17                        Karumuri Hospital         C  29-07-2014 00:00
# 18                        Karumuri Hospital         C  28-07-2014 00:00
# 19                        Karumuri Hospital         C  27-07-2014 00:00
# 20                     Queens Nri Hospitals         C  05-08-2014 00:00
# 21                KIMS SAI SESHDRI HOSPITAL         C  01-08-2014 00:00
# 22                KIMS SAI SESHDRI HOSPITAL         C  01-08-2014 00:00
# 23                        Karumuri Hospital         C  05-08-2014 00:00
# 24                KIMS SAI SESHDRI HOSPITAL         C  04-08-2014 00:00
# 25                KIMS SAI SESHDRI HOSPITAL         C  02-08-2014 00:00
# 26                KIMS SAI SESHDRI HOSPITAL         C  02-08-2014 00:00
# 27                        Karumuri Hospital         C  03-08-2014 00:00
# 28                KIMS SAI SESHDRI HOSPITAL         C  03-08-2014 00:00
# 29                KIMS SAI SESHDRI HOSPITAL         C  04-08-2014 00:00
#
#       DISCHARGE_DATE Mortality Y / N    MORTALITY_DATE SRC_REGISTRATION
# 0   07-09-2013 00:00              NO               NaN                D
# 1   09-09-2013 00:00              NO               NaN                D
# 2   18-10-2013 00:00              NO               NaN                D
# 3   27-09-2013 00:00              NO               NaN                D
# 4   02-10-2013 00:00              NO               NaN                D
# 5   02-10-2013 00:00              NO               NaN                P
# 6   02-10-2013 00:00              NO               NaN                D
# 7                NaN             YES  23-05-2014 00:00                D
# 8   16-06-2014 00:00              NO               NaN                D
# 9   25-06-2014 00:00              NO               NaN                D
# 10               NaN             YES  16-07-2014 00:00                P
# 11  09-07-2014 00:00              NO               NaN                D
# 12  16-07-2014 00:00              NO               NaN                P
# 13  19-07-2014 00:00              NO               NaN                D
# 14  19-07-2014 00:00              NO               NaN                D
# 15  21-07-2014 00:00              NO               NaN                D
# 16  17-08-2017 00:00              NO               NaN                D
# 17  08-08-2014 00:00              NO               NaN                D
# 18  06-08-2014 00:00              NO               NaN                D
# 19  02-08-2014 00:00              NO               NaN                D
# 20  19-12-2014 00:00             YES  19-12-2014 00:00                D
# 21  05-08-2014 00:00              NO               NaN                D
# 22  05-08-2014 00:00              NO               NaN                D
# 23  14-08-2014 00:00              NO               NaN                D
# 24  11-08-2014 00:00              NO               NaN                D
# 25  06-08-2014 00:00              NO               NaN                D
# 26  06-08-2014 00:00             YES  06-08-2014 00:00               MC
# 27  08-08-2014 00:00              NO               NaN                D
# 28  08-08-2014 00:00              NO               NaN                D
# 29  09-08-2014 00:00              NO               NaN                P

# %%
#@title **To'g'ri javob**
dict = {"Male":"Erkak","Male(child)":"Erkak", "Female":"Ayol","Female(child)":"Ayol","MALE":"Erkak","FEMALE":"Ayol"}
df["SEX"] = df["SEX"].map(dict)

# %% [markdown]
# #### **5-mashq**. Endi xuddi shu SEX columndagi ma'lumotlarni raqamlarga o'zgartiring: Erkaklarni 1 raqamiga, Ayollarni 0 raqamiga o'zgartiring.
# *   Erkak -> 1
# *   Ayol -> 0

# %%
# Javobni shuyerga yozing
df.SEX = df.SEX.map({'Erkak':1, 'Ayol':0})
df.head(30)
# Out:
#     AGE  SEX  CASTE_NAME                       CATEGORY_NAME  \
# 0    56    0          BC                          NEPHROLOGY
# 1    37    1          BC                          NEPHROLOGY
# 2    50    1          BC                          NEPHROLOGY
# 3    45    1          BC                          NEPHROLOGY
# 4    54    1          BC                          NEPHROLOGY
# 5    35    1          OC                          NEPHROLOGY
# 6    52    1          OC                          NEPHROLOGY
# 7    73    1          BC                          NEPHROLOGY
# 8    56    1          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 9    49    1          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 10   52    1          BC                          NEPHROLOGY
# 11   56    1          SC                          CARDIOLOGY
# 12   65    0          SC                          CARDIOLOGY
# 13   75    1          OC                          CARDIOLOGY
# 14   52    1          OC                          CARDIOLOGY
# 15   56    1  Minorities                          CARDIOLOGY
# 16    1    1          OC            COCHLEAR IMPLANT SURGERY
# 17   54    0          SC  CARDIAC AND CARDIOTHORACIC SURGERY
# 18   48    1          OC  CARDIAC AND CARDIOTHORACIC SURGERY
# 19   57    0          OC                          CARDIOLOGY
# 20   55    1          OC                          NEPHROLOGY
# 21   74    0          BC                          CARDIOLOGY
# 22   57    1          BC                          CARDIOLOGY
# 23   56    1          BC  CARDIAC AND CARDIOTHORACIC SURGERY
# 24   31    1          BC  ORTHOPEDIC  SURGERY AND PROCEDURES
# 25   68    1          BC                          CARDIOLOGY
# 26   72    0          BC                          CARDIOLOGY
# 27   66    0          OC                          CARDIOLOGY
# 28   35    1          BC                          CARDIOLOGY
# 29   72    0          SC                          CARDIOLOGY
#
#                                               SURGERY             VILLAGE  \
# 0                    Maintenance Hemodialysis For Crf              Lolugu
# 1                    Maintenance Hemodialysis For Crf           Borivanka
# 2                    Maintenance Hemodialysis For Crf         Kapasakuddi
# 3                    Maintenance Hemodialysis For Crf         Telikipenta
# 4                    Maintenance Hemodialysis For Crf       Thandemvalasa
# 5                    Maintenance Hemodialysis For Crf      Phasigangupeta
# 6                    Maintenance Hemodialysis For Crf        Kranti Nagar
# 7                    Maintenance Hemodialysis For Crf         Bhoghapuram
# 8      Coronary Balloon Angioplasty with stent(00.45)              Vallur
# 9                             Coronary Bypass Surgery             Ward-15
# 10                   Maintenance Hemodialysis For Crf               Rajam
# 11              Management Of Acute MI With Angiogram          Thurlapadu
# 12  Medical Management of  Refractory Cardiac Failure            Pulipadu
# 13  Medical Management of  Refractory Cardiac Failure          Karlapalem
# 14  Medical Management of  Refractory Cardiac Failure             Ward-19
# 15              Management Of Acute MI With Angiogram              Tullur
# 16                           Cochlear Implant Surgery       Phirangipuram
# 17                            Coronary Bypass Surgery           Kolakalur
# 18                            Coronary Bypass Surgery            Vellalur
# 19              Management Of Acute MI With Angiogram       Phirangipuram
# 20                   Maintenance Hemodialysis For Crf  Ayyavari Polavaram
# 21              Management Of Acute MI With Angiogram            4th Ward
# 22              Management Of Acute MI With Angiogram           Kambakaya
# 23                            Coronary Bypass Surgery             Konduru
# 24  Excision Or Other Operations For Scaphoid Frac...          Laxmipuram
# 25              Management Of Acute MI With Angiogram         Matchalesam
# 26              Management Of Acute MI With Angiogram          Meghavaram
# 27              Management Of Acute MI With Angiogram             Chavali
# 28              Management Of Acute MI With Angiogram   Shermahammadpuram
# 29              Management Of Acute MI With Angiogram             Talagam
#
#         PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  CLAIM_AMOUNT  \
# 0   03-08-2013 20:38        12500  22-03-2017 20:25         11000
# 1   06-08-2013 07:26        12500  22-03-2017 20:25         11000
# 2   09-08-2013 18:30        12500  22-03-2017 20:25         11500
# 3   24-08-2013 19:37        12500  22-03-2017 20:25         11000
# 4   28-08-2013 17:03        12500  22-03-2017 20:25         11000
# 5   28-08-2013 17:30        12500  22-03-2017 20:25         11000
# 6   30-08-2013 07:53        12500  22-03-2017 20:25         11000
# 7   02-05-2014 15:11        12500  11-10-2017 19:34          5000
# 8   10-06-2014 17:02        40000  17-02-2017 19:21         40000
# 9   11-06-2014 20:41       115846  17-02-2017 19:21        115846
# 10  25-06-2014 08:45        12500  03-10-2017 20:37          6250
# 11  04-07-2014 15:12        30000  17-02-2017 18:54         30000
# 12  09-07-2014 10:17        40000  17-02-2017 18:54         40000
# 13  10-07-2014 20:59        40000  17-02-2017 18:54         40000
# 14  13-07-2014 18:09        40000  17-02-2017 18:54         25000
# 15  16-07-2014 21:08        30000  17-02-2017 18:54         30000
# 16  20-07-2017 20:20       520000  27-10-2017 19:54        520000
# 17  27-07-2014 18:01       115846  17-02-2017 19:22        108846
# 18  27-07-2014 18:01       115846  17-02-2017 19:22        110846
# 19  28-07-2014 08:37        30000  17-02-2017 18:54         30000
# 20  29-07-2014 14:58        12500  10-01-2017 02:04          2500
# 21  01-08-2014 17:51        30000  09-05-2017 18:35         30000
# 22  01-08-2014 17:49        30000  09-05-2017 18:35         25000
# 23  03-08-2014 15:44       115846  17-02-2017 19:22        110000
# 24  03-08-2014 10:23        15000  09-05-2017 18:35          5000
# 25  03-08-2014 14:53        30000  09-05-2017 18:35         30000
# 26  03-08-2014 12:19        30000  09-05-2017 18:35         10000
# 27  04-08-2014 12:21        30000  17-02-2017 18:54         20000
# 28  04-08-2014 12:15        30000  09-05-2017 18:36         30000
# 29  04-08-2014 18:23        30000  09-05-2017 18:36         25000
#
#                                   HOSP_NAME HOSP_TYPE      SURGERY_DATE  \
# 0   Rims Govt. General Hospital, Srikakulam         G  06-08-2013 00:00
# 1   Rims Govt. General Hospital, Srikakulam         G  08-08-2013 00:00
# 2   Rims Govt. General Hospital, Srikakulam         G  15-08-2013 00:00
# 3   Rims Govt. General Hospital, Srikakulam         G  24-08-2013 00:00
# 4   Rims Govt. General Hospital, Srikakulam         G  31-08-2013 00:00
# 5   Rims Govt. General Hospital, Srikakulam         G  31-08-2013 00:00
# 6             Govt General Hospital Kurnool         G  31-08-2013 00:00
# 7                      Queens Nri Hospitals         C  05-05-2014 00:00
# 8                         Karumuri Hospital         C  14-06-2014 00:00
# 9                         Karumuri Hospital         C  17-06-2014 00:00
# 10                     Queens Nri Hospitals         C  27-06-2014 00:00
# 11                        Karumuri Hospital         C  04-07-2014 00:00
# 12                        Karumuri Hospital         C  08-07-2014 00:00
# 13                        Karumuri Hospital         C  10-07-2014 00:00
# 14                        Karumuri Hospital         C  13-07-2014 00:00
# 15                        Karumuri Hospital         C  15-07-2014 00:00
# 16                         Ent Nursing Home         C  16-08-2017 00:00
# 17                        Karumuri Hospital         C  29-07-2014 00:00
# 18                        Karumuri Hospital         C  28-07-2014 00:00
# 19                        Karumuri Hospital         C  27-07-2014 00:00
# 20                     Queens Nri Hospitals         C  05-08-2014 00:00
# 21                KIMS SAI SESHDRI HOSPITAL         C  01-08-2014 00:00
# 22                KIMS SAI SESHDRI HOSPITAL         C  01-08-2014 00:00
# 23                        Karumuri Hospital         C  05-08-2014 00:00
# 24                KIMS SAI SESHDRI HOSPITAL         C  04-08-2014 00:00
# 25                KIMS SAI SESHDRI HOSPITAL         C  02-08-2014 00:00
# 26                KIMS SAI SESHDRI HOSPITAL         C  02-08-2014 00:00
# 27                        Karumuri Hospital         C  03-08-2014 00:00
# 28                KIMS SAI SESHDRI HOSPITAL         C  03-08-2014 00:00
# 29                KIMS SAI SESHDRI HOSPITAL         C  04-08-2014 00:00
#
#       DISCHARGE_DATE Mortality Y / N    MORTALITY_DATE SRC_REGISTRATION
# 0   07-09-2013 00:00              NO               NaN                D
# 1   09-09-2013 00:00              NO               NaN                D
# 2   18-10-2013 00:00              NO               NaN                D
# 3   27-09-2013 00:00              NO               NaN                D
# 4   02-10-2013 00:00              NO               NaN                D
# 5   02-10-2013 00:00              NO               NaN                P
# 6   02-10-2013 00:00              NO               NaN                D
# 7                NaN             YES  23-05-2014 00:00                D
# 8   16-06-2014 00:00              NO               NaN                D
# 9   25-06-2014 00:00              NO               NaN                D
# 10               NaN             YES  16-07-2014 00:00                P
# 11  09-07-2014 00:00              NO               NaN                D
# 12  16-07-2014 00:00              NO               NaN                P
# 13  19-07-2014 00:00              NO               NaN                D
# 14  19-07-2014 00:00              NO               NaN                D
# 15  21-07-2014 00:00              NO               NaN                D
# 16  17-08-2017 00:00              NO               NaN                D
# 17  08-08-2014 00:00              NO               NaN                D
# 18  06-08-2014 00:00              NO               NaN                D
# 19  02-08-2014 00:00              NO               NaN                D
# 20  19-12-2014 00:00             YES  19-12-2014 00:00                D
# 21  05-08-2014 00:00              NO               NaN                D
# 22  05-08-2014 00:00              NO               NaN                D
# 23  14-08-2014 00:00              NO               NaN                D
# 24  11-08-2014 00:00              NO               NaN                D
# 25  06-08-2014 00:00              NO               NaN                D
# 26  06-08-2014 00:00             YES  06-08-2014 00:00               MC
# 27  08-08-2014 00:00              NO               NaN                D
# 28  08-08-2014 00:00              NO               NaN                D
# 29  09-08-2014 00:00              NO               NaN                P

# %%
#@title **To'g'ri javob**
dict2 = {'Erkak':1, 'Ayol':0}
df["SEX"] = df["SEX"].map(dict2)
df.head(5)

# %% [markdown]
# #### **6-mashq**. Shu jarayonni HOSP_TYPE ustuni uchun ham amalga oshiring.
# *   G - General hospital (umumiy kasalxona) degani
# *   C - Special hospital (maxsus kasalxona) degani
# <br><b>O'zgarish quyidagicha bo'lsin:</b>
# *   G -> Umumiy
# *   C -> Maxsus

# %%
# Javobni shuyerga yozing

df["HOSP_TYPE"] = df["HOSP_TYPE"].map({'G':"Umumiy", 'C':"Maxsus"})

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"] = df["HOSP_TYPE"].map({'G':"Umumiy", 'C':"Maxsus"})

# %% [markdown]
# #### **7-mashq**. O'zgartirish amalga oshirilgach, HOSP_TYPE ustunida qancha Umumiy va qancha Maxsus kasalxonalar borligini ham aniqlang

# %%
# Javobni shuyerga yozing
df[df['HOSP_TYPE'] == 'Umumiy'].shape
# Out:
# (94255, 17)

# %%
df[df['HOSP_TYPE'] == 'Maxsus'].shape
# Out:
# (241139, 17)

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"].value_counts()
# Out:
# Maxsus    241139
# Umumiy     94255
# Name: HOSP_TYPE, dtype: int64

# %% [markdown]
# #### **8-mashq**. Datasetda qancha takrorlangan qatorlar borligini aniqlang

# %%
# Javobni shuyerga yozing

# %%
#@title **To'g'ri javob**
sum(df.duplicated())
# Out:
# 30

# %% [markdown]
# #### **9-mashq**. Datasetda barcha takrorlangan qatorlarni o'chirib yuboring

# %%
# Javobni shuyerga yozing

df.drop_duplicates()
# Out:
#         AGE  SEX CASTE_NAME             CATEGORY_NAME  \
# 0        56    0         BC                NEPHROLOGY
# 1        37    1         BC                NEPHROLOGY
# 2        50    1         BC                NEPHROLOGY
# 3        45    1         BC                NEPHROLOGY
# 4        54    1         BC                NEPHROLOGY
# ...     ...  ...        ...                       ...
# 335389   65    1         SC    OPHTHALMOLOGY  SURGERY
# 335390   54    0         OC          MEDICAL ONCOLOGY
# 335391   19    0         SC          MEDICAL ONCOLOGY
# 335392   50    1         BC  GENITO URINARY SURGERIES
# 335393   46    0         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 1                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 2                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 3                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 4                 Rims Govt. General Hospital, Srikakulam    Umumiy
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital    Maxsus
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...    Maxsus
# 335391                                    M.N.J.Hospitals    Umumiy
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL    Maxsus
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...    Maxsus
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335364 rows x 17 columns]

# %%
sum(df.duplicated())
# Out:
# 30

# %%
#@title **To'g'ri javob**
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### **10-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning o'rtacha qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()
# Out:
# HOSP_TYPE
# Maxsus    30275.151848
# Umumiy    22683.770100
# Name: CLAIM_AMOUNT, dtype: float64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()
# Out:
# HOSP_TYPE
# Maxsus    30275.151848
# Umumiy    22683.770100
# Name: CLAIM_AMOUNT, dtype: float64

# %% [markdown]
# #### **11-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning minimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing

df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()
# Out:
# HOSP_TYPE
# Maxsus    2
# Umumiy    2
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()

# %% [markdown]
# #### **12-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), CLAIM_AMOUNTning maksimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing


df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()
# Out:
# HOSP_TYPE
# Maxsus    520000
# Umumiy    520000
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()

# %% [markdown]
# .agg() yordamida istalgan funksiyalarni chaqirishimiz mumkin, misol uchun numpy dagi mean (o'rta qiymat) funiksiyasini ham qo'shamiz. Natijalarni faqat price ustuni uchun chiqaramiz:

# %% [markdown]
# #### **13-mashq**. Datasetdan jinsiga ko'ra CLAIM_AMOUNTning min, max va o'rta qiymatlarni agg() usuli yordamida toping.

# %%
# Javobni shuyerga yozing

df.groupby('SEX').CLAIM_AMOUNT.agg([min, max, np.mean])
# Out:
#      min     max          mean
# SEX
# 0      2  520000  25960.356579
# 1      2  520000  29586.732405

# %%
#@title **To'g'ri javob**
df.groupby('SEX').CLAIM_AMOUNT.agg([min, max, np.mean])
