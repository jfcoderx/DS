# %% [markdown]
# <a href="https://colab.research.google.com/github/jfcoderx/Data-Sciense/blob/main/04_VISUAL_AMALIYOT_02_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 4-MODUL. VIZUALIZASIYA
#
# ## 2-AMALIYOT. `seaborn`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 1-VAZIFA. Avvalgi [amaliyotda](https://colab.research.google.com/drive/1jzhJ1gN6msILYOHaG2fhBBvUGaa4tcLf?usp=sharing) saqlangan faylni yangi `df`ga o'qing

# %%
#JAVOBINGIZNI SHU YERGA YOZING
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# hdf5 formatdagi fayllarimizni ochib olyapmiz:

# %%
cl = pd.HDFStore('/content/drive/MyDrive/Colab Notebooks/DATASETS/avg_climate_tash.h5')
cl.keys()
# Out:
# ['/climate', '/col_info']

# %%
df = cl['climate']
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0

# %%
df2 = cl['col_info']
df2.head()
# Out:
#                                           1  \
# 0
# T                Average annual temperature
# TM       Annual average maximum temperature
# Tm       Average annual minimum temperature
# PP  Rain or snow precipitation total annual
# V                 Annual average wind speed
#
#                                           2
# 0
# T                   o'rtacha yillik harorat
# TM         Yillik o'rtacha maksimal harorat
# Tm          O'rtacha yillik minimal harorat
# PP  Yillik jami yomg'ir yoki qor yog'inlari
# V            Yillik o'rtacha shamol tezligi

# %%
cl.close()

# %% [markdown]
# ### 2-VAZIFA. `df` barcha ustunlarini chiziqli grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16, 8))
sns.lineplot(data=df)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Yil")
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Grafiklar nomini to'g'rilang (`T`, `Tm` va hokazo matnlarni o'zbek tilida chiqaring.)

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16, 8))
sns.lineplot(data=df, linewidth=2.0)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Y I L")
plt.ylabel("H A R O R A T")

plt.legend(['Yillik ortacha harorat',
            'Yillik ortacha maksimal harorat',
            'Yillik ortacha minimal harorat',
            'Yillik ortacha shamok tezligi',
            'Yomgirli kunlar soni',
            'Qorli kunlar soni',  
            'Boronli kunlar soni',
            'Tumanli kunlar soni',
            'Tornadoli kunlar soni',
            'Dol yoqqan kunlar soni'], loc=1)
plt.show()

# %% [markdown]
# ### 4-VAZIFA. Yuqoridagi grafikda turli ko'rsatkichlar aralashib ketdi. Keling ustun turiga qarab alohida grafiklar chizamiz.
#
# #### 4.1. Haroratni ko'rsatuvchi ustunlarni alohida chiziqli grafik qilib chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16, 8))
sns.lineplot(data=df[['T', 'TM', 'Tm']], linewidth=2.0)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Y I L")
plt.ylabel("H A R O R A T")

plt.legend(['Yillik ortacha harorat',
            'Yillik ortacha maksimal harorat',
            'Yillik ortacha minimal harorat'], loc=0)
plt.show()

# %% [markdown]
# #### 4.2. Kunlarni ko'rsatuvchi ustunlarni alohida grafik ko'rinishida chiqaring

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16, 8))
sns.lineplot(data=df[["RA",	"SN",	"TS",	"FG",	"TN",	"GR"]], linewidth=2.0)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("Y I L")
plt.ylabel("H A R O R A T")

plt.legend(['Yomgirli kunlar soni',
            'Qorli kunlar soni',  
            'Boronli kunlar soni',
            'Tumanli kunlar soni',
            'Tornadoli kunlar soni',
            'Dol yoqqan kunlar soni'], loc=0)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. Yillik o'rtacha shamol tezligini ustunli grafik ko'rinishida chiqaring.

# %%
df
# Out:
#          T    TM    Tm     V     RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2   8.3   5.1   77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8   8.6   5.1   93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6   7.6   5.4   98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1   8.0   5.1   66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2   8.4   4.4   41.0  20.0   8.0  12.0  0.0  0.0
# 1996  14.0  20.5   7.6   5.0   68.0  23.0  14.0  13.0  0.0  0.0
# 1997  15.7  22.0   8.8   8.2   91.4  24.3  13.8  23.9  0.0  0.0
# 1998  15.7  22.0   8.8   8.2   91.4  24.3  13.8  23.9  0.0  0.0
# 1999  15.7  22.4   8.9   7.6   98.0  15.0  13.0  18.0  0.0  0.0
# 2000  16.0  22.5   9.1   8.0   84.0  19.0  11.0  25.0  0.0  2.0
# 2001  16.3  22.7   9.2   8.2   80.0  20.0  12.0  23.0  1.0  0.0
# 2002  15.7  22.0   8.8   8.2   92.0  35.0  13.0  28.0  0.0  0.0
# 2003  15.6  21.7   8.9   7.8  109.0  22.0  13.0  19.0  0.0  1.0
# 2004  16.6  22.8   9.6   7.7  104.0  17.0   7.0  34.0  0.0  0.0
# 2005  15.7  22.0   8.8   8.2   91.4  24.3  13.8  23.9  0.0  0.0
# 2006  16.4  22.6   9.0   9.1   93.0  29.0  21.0  44.0  0.0  0.0
# 2007  16.2  22.6   8.5   9.0   86.0  17.0  16.0  37.0  0.0  0.0
# 2008  15.9  22.3   8.4   8.8   75.0  34.0   7.0  45.0  0.0  3.0
# 2009  16.1  22.3   8.7   9.0  119.0  12.0  22.0  31.0  0.0  1.0
# 2010  16.8  23.3   9.4   9.0  109.0  13.0  27.0  27.0  0.0  0.0
# 2011  15.8  21.8   8.6   9.5  105.0  41.0  16.0  50.0  0.0  0.0
# 2012  15.0  21.4   7.9   9.4   86.0  40.0  23.0  28.0  0.0  2.0
# 2013  16.3  22.6   9.1   9.6   90.0  29.0  17.0  22.0  0.0  0.0
# 2014  14.9  21.2   7.8   9.5   96.0  30.0  13.0  34.0  0.0  2.0
# 2015  16.3  22.3   9.6   9.9  119.0  23.0  19.0  14.0  0.0  0.0
# 2016  16.8  23.3   9.9   9.9  102.0  24.0  11.0   6.0  0.0  0.0
# 2017  16.0  22.3   9.0   9.9   92.0  27.0  14.0  31.0  0.0  0.0
# 2018  16.0  22.4   9.3   9.7   92.0  16.0   9.0  30.0  0.0  0.0
# 2019  16.6  22.5  10.0   9.8  111.0  16.0  12.0  19.0  0.0  0.0
# 2020  15.5  21.3   9.2   9.8   92.0  37.0  18.0  26.0  0.0  0.0
# 2021  17.0  23.4  10.1  10.0   82.0  11.0  10.0  14.0  0.0  0.0
# 2022  15.7  22.0   8.8   8.2   91.4  24.3  13.8  23.9  0.0  0.0

# %%
#JAVOBINGIZNI SHU YERGA YOZING
plt.figure(figsize=(16, 6))
sns.barplot(x=df.index, y=df['V'])

plt.title("Yillik o'rtacha shamol tezligining ustunli grafiki")
plt.xlabel('Y I L L A R')
plt.ylabel('ORTACHA SHAMOL TEZLIGI (KM/SOAT)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 6-VAZIFA. Yomg'rili, qorli, bo'ronli, tumanli va do'l yoqqan kunlar sonini heatmap ko'rinishida chiqaring.

# %%
#JAVOBINGIZNI SHU YERGA YOZING
df.head(10)
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2  8.4  4.4  41.0  20.0   8.0  12.0  0.0  0.0
# 1996  14.0  20.5  7.6  5.0  68.0  23.0  14.0  13.0  0.0  0.0
# 1997  15.7  22.0  8.8  8.2  91.4  24.3  13.8  23.9  0.0  0.0
# 1998  15.7  22.0  8.8  8.2  91.4  24.3  13.8  23.9  0.0  0.0
# 1999  15.7  22.4  8.9  7.6  98.0  15.0  13.0  18.0  0.0  0.0
# 2000  16.0  22.5  9.1  8.0  84.0  19.0  11.0  25.0  0.0  2.0

# %%
df2
# Out:
#                                           1  \
# 0
# T                Average annual temperature
# TM       Annual average maximum temperature
# Tm       Average annual minimum temperature
# PP  Rain or snow precipitation total annual
# V                 Annual average wind speed
# RA                 Number of days with rain
# SN                 Number of days with snow
# TS                Number of days with storm
# FG                     Number of foggy days
# TN              Number of days with tornado
# GR                 Number of days with hail
#
#                                           2
# 0
# T                   o'rtacha yillik harorat
# TM         Yillik o'rtacha maksimal harorat
# Tm          O'rtacha yillik minimal harorat
# PP  Yillik jami yomg'ir yoki qor yog'inlari
# V            Yillik o'rtacha shamol tezligi
# RA                    Yomg'irli kunlar soni
# SN                        Qorli kunlar soni
# TS                     Bo'ronli kunlar soni
# FG                      Tumanli kunlar soni
# TN                Tornado bilan kunlar soni
# GR              Do'l yog'adigan kunlar soni

# %%
dd = df[["RA",	"SN",	"TS",	"FG",	"GR"]]
dd.columns = ['Yomgir', 'Qor', 'Boron', 'Tuman', 'Dol']

# %%
dd
# Out:
#       Yomgir   Qor  Boron  Tuman  Dol
# Year
# 1991    77.0  26.0   15.0   17.0  1.0
# 1992    93.0  19.0    9.0    2.0  1.0
# 1993    98.0  38.0   12.0   10.0  0.0
# 1994    66.0  28.0    4.0    9.0  0.0
# 1995    41.0  20.0    8.0   12.0  0.0
# 1996    68.0  23.0   14.0   13.0  0.0
# 1997    91.4  24.3   13.8   23.9  0.0
# 1998    91.4  24.3   13.8   23.9  0.0
# 1999    98.0  15.0   13.0   18.0  0.0
# 2000    84.0  19.0   11.0   25.0  2.0
# 2001    80.0  20.0   12.0   23.0  0.0
# 2002    92.0  35.0   13.0   28.0  0.0
# 2003   109.0  22.0   13.0   19.0  1.0
# 2004   104.0  17.0    7.0   34.0  0.0
# 2005    91.4  24.3   13.8   23.9  0.0
# 2006    93.0  29.0   21.0   44.0  0.0
# 2007    86.0  17.0   16.0   37.0  0.0
# 2008    75.0  34.0    7.0   45.0  3.0
# 2009   119.0  12.0   22.0   31.0  1.0
# 2010   109.0  13.0   27.0   27.0  0.0
# 2011   105.0  41.0   16.0   50.0  0.0
# 2012    86.0  40.0   23.0   28.0  2.0
# 2013    90.0  29.0   17.0   22.0  0.0
# 2014    96.0  30.0   13.0   34.0  2.0
# 2015   119.0  23.0   19.0   14.0  0.0
# 2016   102.0  24.0   11.0    6.0  0.0
# 2017    92.0  27.0   14.0   31.0  0.0
# 2018    92.0  16.0    9.0   30.0  0.0
# 2019   111.0  16.0   12.0   19.0  0.0
# 2020    92.0  37.0   18.0   26.0  0.0
# 2021    82.0  11.0   10.0   14.0  0.0
# 2022    91.4  24.3   13.8   23.9  0.0

# %%
plt.figure(figsize=(22,4))
sns.heatmap(data=dd.T, cmap='YlGnBu', linewidths=1, square=True)
plt.title("Toshkent shahri yillik ob-havo ko'rsatkichlari")
plt.xlabel("YEAR")
plt.show()

# %%
#@title Kutilgan natija:
plt.figure(figsize=(30,5))
sns.heatmap(data=df[['RA','SN','TS','FG','GR']].T, cmap="YlGnBu", linewidths=1, square=True)
plt.title("Toshkent shahri uchun ob havo ko'rsatkichlari")
yticks_labels = ["Yomg'ir","Qor","Bo'ron","Tuman","Do'l"]
plt.yticks(np.arange(5)+0.5, labels=yticks_labels)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()
